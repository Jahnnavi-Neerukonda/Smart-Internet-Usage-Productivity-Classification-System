# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/raw_data.csv")

# %%
print(df.head())
# Out:
#   website_category  time_spent  frequency day_type productivity_label  \
# 0        Education         120          5  Weekday         Productive
# 1           Coding         180          4  Weekday         Productive
# 2     Social Media          90          8  Weekend       Unproductive
# 3    Entertainment         110          6  Weekend       Unproductive
# 4        Education          60          3  Weekday         Productive
#
#    productivity_score
# 0                  85
# 1                  90
# 2                  25
# 3                  30
# 4                  70

# %%
print(df.describe())
# Out:
#        time_spent  frequency  productivity_score
# count   10.000000  10.000000           10.000000
# mean   108.500000   4.800000           58.000000
# std     54.876123   1.813529           28.693786
# min     40.000000   2.000000           20.000000
# 25%     67.500000   4.000000           31.250000
# 50%    100.000000   4.500000           62.500000
# 75%    142.500000   5.750000           82.500000
# max    200.000000   8.000000           95.000000

# %%
df['productivity_label'].value_counts().plot(kind='bar')
plt.title("Productivity Label Distribution")
plt.show()
